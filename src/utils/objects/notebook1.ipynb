# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import json
from pathlib import Path

# %%
datafile = Path("/Users/wulfmanc/gh/perseus-aa/json/vases.json")

# %%
from utils.objects.models import Vase

# %%
with open(datafile, 'r', encoding='utf-8') as f:
    data = json.load(f)

vases = [Vase(**v) for v in data]

# %%
len(vases)
# Out:
# 1909

# %%
{v.collection for v in vases}
# Out:
# {'Ackland Art Museum, University of North Carolina, Chapel Hill',
#  'Allen Memorial Art Museum',
#  'Ancona, Archeologico Museo Regionale delle Marche',
#  'Anonymous Collection',
#  'Archer M. Huntington Art Gallery, University of Texas at Austin',
#  'Arezzo, Museo Civico',
#  'Art Institute of Chicago',
#  'Athens, Agora Museum',
#  'Athens, Fethiye Djami',
#  'Athens, National Archaeological Museum',
#  'Baltimore, Walters Art Gallery',
#  'Basel, H.A. Cahn Collection',
#  'Beloit College, Wright Museum of Art',
#  'Berlin, Antikenmuseen',
#  'Birmingham Museum of Art',
#  'Bologna, Museo Civico',
#  'Bowdoin College Museum of Art',
#  'Brussels, Muses Royaux de Cinquantenaire',
#  'Budapest, Szepmuveszeti',
#  'Cambridge, Harvard University Art Museums',
#  'Chiusi, Museo Civico',
#  'Cincinnati Art Museum',
#  'Cleveland Museum of Art',
#  'Collection of Costas Lemonopoulos, St. Petersburg',
#  'Collection of Dr. Warren Gilson',
#  'Collection of Emily D. B. Vermeule',
# ...
